# %% [markdown]
# # Rotta EQ Discovery
#
# *Authors: Antony Sikorski*
#
# A simpler notebook for EQ discovery for the Rotta model. We do this with the `PySR` package for symbolic regression, an ML method for finding interpretable symbolic expressions.

# %%
#importing libraries
# from pdfs import *
import os
import re

import xarray as xr
import netCDF4 as nc
import h5netcdf

import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display
import pandas as pd

import pysr
from pysr import PySRRegressor

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
# Out:
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython

# %% [markdown]
# ### Functions:

# %%
def list_directories_files(path):
    """
    provides all files and directories from the LES simulations (they start with Ug)

    Parameters:
    - path (str): The path to the LES simulation data.

    Returns:
    - directories (list): A list of all directories starting with 'Ug'.
    - files (list): A list of all files starting with 'Ug'.
    """

    # all items in the given path
    items = os.listdir(path)
    
    # find the directories starting with 'Ug'
    directories = [item for item in items if os.path.isdir(os.path.join(path, item)) and item.startswith('Ug')]
    # find the files starting with 'Ug'
    files = [item for item in items if os.path.isfile(os.path.join(path, item)) and item.startswith('Ug')]
    
    return directories, files

# %%
def time_average(data, timeavg):
    """
    Averages an array over specified number of time steps. Works for both 1D and higher-dimensional arrays.

    Parameters:
    - data (numpy.ndarray): The input data array. Expected shapes are either (ntime,) or (ntime, nz).
    - timeavg (int): The number of time steps over which to average.

    Returns:
    - numpy.ndarray: The averaged data array.
    """
    ntime = data.shape[0]
    nchunks = ntime // timeavg
    truncated_data = data[:nchunks * timeavg]

    if data.ndim == 1:
        # for 1D arrays, reshape to (nchunks, timeavg)
        reshaped_data = truncated_data.reshape(nchunks, timeavg)
    else:
        # for 2D arrays, old method with reshaping
        nz = data.shape[1]
        reshaped_data = truncated_data.reshape(nchunks, timeavg, nz)

    # compute the mean along the new time axis 
    averaged_data = reshaped_data.mean(axis=1)

    return averaged_data

# %%
def make_variables(path, items, time_avg):
    """
    Extracts the variables of interest from the LES simulations and averages them over specified number of time steps.

    Parameters:
    - path (str): The path to the LES simulation data.
    - items (list): A list of files containing the LES simulation data.
    - time_avg (int): The number of time steps over which to average.

    Returns:
    - all variables (numpy.ndarray)
    """

    # Initialize empty lists to accumulate results
    sigma_th = []
    sigma_2 = []
    Theta = []
    wtheta = []
    wwtheta = []
    rdstr = []
    transport = []

    for item in items:
        ds_stat = nc.Dataset(os.path.join(path, item), mode='r')
        
        sigma_th_temp = time_average(ds_stat.groups['thermo']['th_2'][:], time_avg)  # covariance of theta
        sigma_2_temp = time_average(ds_stat.groups['default']['w_2'][:], time_avg)   # covariance of w
        Theta_temp = time_average(ds_stat.groups['thermo']['th'][:], time_avg)       # domain mean theta
        wtheta_temp = time_average(ds_stat.groups['thermo']['th_flux'][:], time_avg) # heat flux
        wwtheta_temp = time_average(ds_stat.groups['budget']['wwtheta'][:], time_avg) # third moment, covariance between wtheta and w
        rdstr_temp = time_average(ds_stat.groups['budget']['bw_rdstr'][:], time_avg) # pressure redistribution term
        transport_temp = time_average(ds_stat.groups['budget']['bw_pres'][:], time_avg) # pressure transport term

        # Append the results to the respective lists
        sigma_th.append(sigma_th_temp)
        sigma_2.append(sigma_2_temp)
        Theta.append(Theta_temp)
        wtheta.append(wtheta_temp)
        wwtheta.append(wwtheta_temp)
        rdstr.append(rdstr_temp)
        transport.append(transport_temp)

    # Concatenate the results along the time axis
    sigma_th = np.concatenate(sigma_th, axis=0)
    sigma_2 = np.concatenate(sigma_2, axis=0)
    Theta = np.concatenate(Theta, axis=0)
    wtheta = np.concatenate(wtheta, axis=0)
    wwtheta = np.concatenate(wwtheta, axis=0)
    rdstr = np.concatenate(rdstr, axis=0)
    transport = np.concatenate(transport, axis=0)

    return sigma_th, sigma_2, Theta, wtheta, wwtheta, rdstr, transport

# %%
def reshape_variables(variable):
    reshaped = (variable[:, :-1] + variable[:, 1:]) / 2.0
    return reshaped


def extract_ug_q(filename):
    # Extracting 'ug' and 'q' from the filename
    match = re.search(r'Ug(\d+)Q(\d+)', filename)
    ug = int(match.group(1))
    q = int(match.group(2))

    return ug, q

# %%
def make_constants(path, items, time_avg):
    """
    Extracts the constants of interest from the LES simulations and averages them over specified number of time steps.

    Parameters:
    - path (str): The path to the LES simulation data.
    - items (list): A list of files containing the LES simulation data.
    - time_avg (int): The number of time steps over which to average.

    Returns:
    - all constants (numpy.ndarray)
    """
    wtheta_surface = []
    pbl_height = []
    wstar = []
    theta_star = []
    scaling = []
    ustar = []
    grr = 9.8
    T_0 = 300
    beta = grr/T_0
    ug = []
    q = []

    for item in items:
        ds_stat = nc.Dataset(os.path.join(path, item), mode='r')

        wtheta_surface_raw = ds_stat.groups['thermo']['th_flux'][:,0] 
        wtheta_surface_temp = time_average(wtheta_surface_raw, time_avg)

        pbl_height_raw = ds_stat.groups['thermo'].variables['zi'][:] 
        pbl_height_temp = time_average(pbl_height_raw, time_avg)

        wstar_raw = np.power( beta * (wtheta_surface_raw) * pbl_height_raw , 1/3) 
        wstar_temp = time_average(wstar_raw, time_avg)

        theta_star_raw = wtheta_surface_raw / wstar_raw
        theta_star_temp = time_average(theta_star_raw, time_avg)

        scaling_raw = wstar_raw**2 * theta_star_raw / pbl_height_raw
        scaling_temp = time_average(scaling_raw, time_avg)

        ustar_temp = time_average(ds_stat.groups['default'].variables['ustar'][:], time_avg)

        ug_val, q_val = extract_ug_q(item)
        # ug = np.ma.masked_array(np.full(wtheta_surface_temp.shape, ug_val), mask=wtheta_surface_temp.mask)
        # q = np.ma.masked_array(np.full(wtheta_surface_temp.shape, q_val), mask=wtheta_surface_temp.mask)
        ug_repeat = np.full(wtheta_surface_temp.shape, ug_val)
        q_repeat = np.full(wtheta_surface_temp.shape, q_val)

        wtheta_surface.append(wtheta_surface_temp)
        pbl_height.append(pbl_height_temp)
        wstar.append(wstar_temp)
        theta_star.append(theta_star_temp)
        scaling.append(scaling_temp)
        ustar.append(ustar_temp)
        ug.append(ug_repeat)
        q.append(q_repeat)

    wtheta_surface = np.concatenate(wtheta_surface, axis=0)
    pbl_height = np.concatenate(pbl_height, axis=0)
    wstar = np.concatenate(wstar, axis=0)
    theta_star = np.concatenate(theta_star, axis=0)
    scaling = np.concatenate(scaling, axis=0)
    ustar = np.concatenate(ustar, axis=0)
    ug = np.concatenate(ug, axis=0)
    q = np.concatenate(q, axis=0)

    wtheta_surface = wtheta_surface[:,np.newaxis]
    pbl_height = pbl_height[:,np.newaxis]
    wstar = wstar[:,np.newaxis]
    theta_star = theta_star[:,np.newaxis]
    scaling = scaling[:,np.newaxis]
    ustar = ustar[:,np.newaxis]
    ug = ug[:,np.newaxis]
    q = q[:,np.newaxis]

    return wtheta_surface, pbl_height, wstar, theta_star, scaling, ustar, grr, T_0, beta, ug, q

# %% [markdown]
# ### Data Processing

# %% [markdown]
# This lists all of our files. **If someone else is using this notebook, all that needs to be changed to reproduce results is the path.**

# %%
path = 'C:/Users/anton/Desktop/Career/LEAP_nyc_Summer2024/les_sim_2/'


directories, files = list_directories_files(path)
print("Directories starting with 'Ug':", directories)
print("Files starting with 'Ug':", files)
# Out:
# Directories starting with 'Ug': []
# Files starting with 'Ug': ['Ug16Q000_IV.nc', 'Ug16Q001_IV.nc', 'Ug16Q003_IV.nc', 'Ug16Q006_I.nc', 'Ug16Q006_IV.nc', 'Ug16Q010_IV.nc', 'Ug1Q01_II.nc', 'Ug2Q010_I.nc', 'Ug2Q010_IV.nc', 'Ug2Q01_III.nc', 'Ug2Q024_I.nc', 'Ug8Q003_II.nc', 'Ug8Q003_III.nc', 'Ug8Q003_IV.nc', 'Ug8Q006_IV.nc']

# %%
items = files

# %% [markdown]
# Let's see which ones have the budget category (we need variables from it):

# %%
for item in items:
    ds_stat = nc.Dataset( os.path.join(path, item), mode='r')
    if 'budget' in ds_stat.groups:
        print ("budget is in", item)
    else:
        print ("budget is not in", item)
# Out:
# budget is not in Ug16Q000_IV.nc
# budget is in Ug16Q001_IV.nc
# budget is in Ug16Q003_IV.nc
# budget is in Ug16Q006_I.nc
# budget is in Ug16Q006_IV.nc
# budget is in Ug16Q010_IV.nc
# budget is in Ug1Q01_II.nc
# budget is in Ug2Q010_I.nc
# budget is in Ug2Q010_IV.nc
# budget is in Ug2Q01_III.nc
# budget is in Ug2Q024_I.nc
# budget is in Ug8Q003_II.nc
# budget is in Ug8Q003_III.nc
# budget is in Ug8Q003_IV.nc
# budget is in Ug8Q006_IV.nc

# %% [markdown]
# It appears that we can use all files except the very first (`000`) file. Going to print out all of the viable files so we can see dimension sizes and groups:

# %%
for item in items[1:]:
    print(item)
    df = nc.Dataset(path + '/' + item, mode='r')
    print(df)
# Out:
# Ug16Q001_IV.nc
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     dimensions(sizes): z(384), zh(385), time(120)
#     variables(dimensions): float64 time(time), float64 z(z), float64 zh(zh)
#     groups: default, thermo, budget
# Ug16Q003_IV.nc
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     dimensions(sizes): z(384), zh(385), time(120)
#     variables(dimensions): float64 time(time), float64 z(z), float64 zh(zh)
#     groups: default, thermo, budget
# Ug16Q006_I.nc
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     dimensions(sizes): z(256), zh(257), time(120)
#     variables(dimensions): float64 time(time), float64 z(z), float64 zh(zh)
#     groups: default, thermo, budget
# Ug16Q006_IV.nc
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     dimensions(sizes): z(384), zh(385), time(90)
#     variables(dimensions): float64 time(time), float64 z(z), float64 zh(zh)
#     groups: default, thermo, budget
# Ug16Q010_IV.nc
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     dimensions(sizes): z(384), zh(385), time(90)
#     variables(dimensions): float64 time(time), float64 z(z), float64 zh(zh)
#     groups: default, thermo, budget
# Ug1Q01_II.nc
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     dimensions(sizes): z(384), zh(385), time(120)
#     variables(dimensions): float64 time(time), float64 z(z), float64 zh(zh)
#     groups: default, thermo, budget
# Ug2Q010_I.nc
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     dimensions(sizes): z(256), zh(257), time(120)
#     variables(dimensions): float64 time(time), float64 z(z), float64 zh(zh)
#     groups: default, thermo, budget
# Ug2Q010_IV.nc
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     dimensions(sizes): z(384), zh(385), time(90)
#     variables(dimensions): float64 time(time), float64 z(z), float64 zh(zh)
#     groups: default, thermo, budget
# Ug2Q01_III.nc
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     dimensions(sizes): z(384), zh(385), time(120)
#     variables(dimensions): float64 time(time), float64 z(z), float64 zh(zh)
#     groups: default, thermo, budget
# Ug2Q024_I.nc
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     dimensions(sizes): z(256), zh(257), time(120)
#     variables(dimensions): float64 time(time), float64 z(z), float64 zh(zh)
#     groups: default, thermo, budget
# Ug8Q003_II.nc
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     dimensions(sizes): z(384), zh(385), time(120)
#     variables(dimensions): float64 time(time), float64 z(z), float64 zh(zh)
#     groups: default, thermo, budget
# Ug8Q003_III.nc
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     dimensions(sizes): z(384), zh(385), time(120)
#     variables(dimensions): float64 time(time), float64 z(z), float64 zh(zh)
#     groups: default, thermo, budget
# Ug8Q003_IV.nc
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     dimensions(sizes): z(384), zh(385), time(120)
#     variables(dimensions): float64 time(time), float64 z(z), float64 zh(zh)
#     groups: default, thermo, budget
# Ug8Q006_IV.nc
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     dimensions(sizes): z(384), zh(385), time(120)
#     variables(dimensions): float64 time(time), float64 z(z), float64 zh(zh)
#     groups: default, thermo, budget

# %% [markdown]
# This should create selected files for a given list of `items`. In my case, my `selected_files` constitutes a group of similar (I think) simulations that I can append together for the sake of having more data. For now (for ease of use) I want them all to have the same `z` and `zh` dimensions.

# %%
target_z_dim = 384

selected_files = []

for item in items[1:]:
        df = nc.Dataset(os.path.join(path, item), mode='r')
        if df.dimensions['z'].size == target_z_dim:
            selected_files.append(item)
        df.close()

print(len(selected_files))
print(len(items))
print(selected_files)
# Out:
# 11
# 15
# ['Ug16Q001_IV.nc', 'Ug16Q003_IV.nc', 'Ug16Q006_IV.nc', 'Ug16Q010_IV.nc', 'Ug1Q01_II.nc', 'Ug2Q010_IV.nc', 'Ug2Q01_III.nc', 'Ug8Q003_II.nc', 'Ug8Q003_III.nc', 'Ug8Q003_IV.nc', 'Ug8Q006_IV.nc']

# %% [markdown]
# Let's take a look at all of the variables inside an example file:

# %%
example_df = nc.Dataset(os.path.join(path, selected_files[1]), mode='r')

for group_name, group in example_df.groups.items():
    print(f"Group: {group_name}")
    for var_name, var in group.variables.items():
        long_name = var.getncattr('long_name') if 'long_name' in var.ncattrs() else 'No long_name attribute'
        print(f"  Variable: {var_name}, Long Name: {long_name}")
# Out:
# Group: default
#   Variable: iter, Long Name: Iteration number
#   Variable: area, Long Name: Fractional area contained in mask
#   Variable: areah, Long Name: Fractional area contained in mask
#   Variable: eft, Long Name: eft
#   Variable: eft_3, Long Name: Moment 3 of the eft
#   Variable: eft_4, Long Name: Moment 4 of the eft
#   Variable: eft_diff, Long Name: Diffusive flux of the eft
#   Variable: eft_w, Long Name: Turbulent flux of the eft
#   Variable: eft_grad, Long Name: Gradient of the eft
#   Variable: eft_2, Long Name: Moment 2 of the eft
#   Variable: eft_path, Long Name: eft path
#   Variable: eft_flux, Long Name: Total flux of the eft
#   Variable: sft, Long Name: sft
#   Variable: sft_3, Long Name: Moment 3 of the sft
#   Variable: sft_4, Long Name: Moment 4 of the sft
#   Variable: sft_diff, Long Name: Diffusive flux of the sft
#   Variable: sft_w, Long Name: Turbulent flux of the sft
#   Variable: sft_grad, Long Name: Gradient of the sft
#   Variable: sft_2, Long Name: Moment 2 of the sft
#   Variable: sft_path, Long Name: sft path
#   Variable: sft_flux, Long Name: Total flux of the sft
#   Variable: u, Long Name: U velocity
#   Variable: u_3, Long Name: Moment 3 of the U velocity
#   Variable: u_4, Long Name: Moment 4 of the U velocity
#   Variable: u_diff, Long Name: Diffusive flux of the U velocity
#   Variable: u_w, Long Name: Turbulent flux of the U velocity
#   Variable: u_grad, Long Name: Gradient of the U velocity
#   Variable: u_2, Long Name: Moment 2 of the U velocity
#   Variable: u_path, Long Name: U velocity path
#   Variable: u_flux, Long Name: Total flux of the U velocity
#   Variable: v, Long Name: V velocity
#   Variable: v_3, Long Name: Moment 3 of the V velocity
#   Variable: v_4, Long Name: Moment 4 of the V velocity
#   Variable: v_diff, Long Name: Diffusive flux of the V velocity
#   Variable: v_w, Long Name: Turbulent flux of the V velocity
#   Variable: v_grad, Long Name: Gradient of the V velocity
#   Variable: v_2, Long Name: Moment 2 of the V velocity
#   Variable: v_path, Long Name: V velocity path
#   Variable: v_flux, Long Name: Total flux of the V velocity
#   Variable: w, Long Name: Vertical velocity
#   Variable: w_3, Long Name: Moment 3 of the Vertical velocity
#   Variable: w_4, Long Name: Moment 4 of the Vertical velocity
#   Variable: w_2, Long Name: Moment 2 of the Vertical velocity
#   Variable: p, Long Name: Pressure
#   Variable: p_grad, Long Name: Gradient of the Pressure
#   Variable: p_2, Long Name: Moment 2 of the Pressure
#   Variable: p_w, Long Name: Turbulent flux of the Pressure
#   Variable: eft_bot, Long Name: Surface eft
#   Variable: sft_bot, Long Name: Surface sft
#   Variable: ustar, Long Name: Surface friction velocity
#   Variable: obuk, Long Name: Obukhov length
#   Variable: evisc, Long Name: Eddy viscosity
#   Variable: evisc_2, Long Name: Moment 2 of the Eddy viscosity
# Group: thermo
#   Variable: th, Long Name: Potential Temperature
#   Variable: th_3, Long Name: Moment 3 of the Potential Temperature
#   Variable: th_4, Long Name: Moment 4 of the Potential Temperature
#   Variable: th_diff, Long Name: Diffusive flux of the Potential Temperature
#   Variable: th_w, Long Name: Turbulent flux of the Potential Temperature
#   Variable: th_grad, Long Name: Gradient of the Potential Temperature
#   Variable: th_2, Long Name: Moment 2 of the Potential Temperature
#   Variable: th_path, Long Name: Potential Temperature path
#   Variable: th_flux, Long Name: Total flux of the Potential Temperature
#   Variable: th_bot, Long Name: Surface Potential Temperature
#   Variable: rhoref, Long Name: Full level basic state density
#   Variable: rhorefh, Long Name: Half level basic state density
#   Variable: thref, Long Name: Full level basic state potential temperature
#   Variable: threfh, Long Name: Half level basic state potential temperature
#   Variable: b, Long Name: Buoyancy
#   Variable: b_3, Long Name: Moment 3 of the Buoyancy
#   Variable: b_4, Long Name: Moment 4 of the Buoyancy
#   Variable: b_diff, Long Name: Diffusive flux of the Buoyancy
#   Variable: b_w, Long Name: Turbulent flux of the Buoyancy
#   Variable: b_grad, Long Name: Gradient of the Buoyancy
#   Variable: b_2, Long Name: Moment 2 of the Buoyancy
#   Variable: b_flux, Long Name: Total flux of the Buoyancy
#   Variable: zi, Long Name: Boundary Layer Depth
# Group: budget
#   Variable: ke, Long Name: Kinetic energy
#   Variable: tke, Long Name: Turbulent kinetic energy
#   Variable: u2_shear, Long Name: Shear production term in U2 budget
#   Variable: v2_shear, Long Name: Shear production term in V2 budget
#   Variable: tke_shear, Long Name: Shear production term in TKE budget
#   Variable: uw_shear, Long Name: Shear production term in UW budget
#   Variable: vw_shear, Long Name: Shear production term in VW budget
#   Variable: u2_turb, Long Name: Turbulent transport term in U2 budget
#   Variable: v2_turb, Long Name: Turbulent transport term in V2 budget
#   Variable: w2_turb, Long Name: Turbulent transport term in W2 budget
#   Variable: tke_turb, Long Name: Turbulent transport term in TKE budget
#   Variable: uw_turb, Long Name: Turbulent transport term in UW budget
#   Variable: vw_turb, Long Name: Turbulent transport term in VW budget
#   Variable: w2_pres, Long Name: Pressure transport term in W2 budget
#   Variable: tke_pres, Long Name: Pressure transport term in TKE budget
#   Variable: uw_pres, Long Name: Pressure transport term in UW budget
#   Variable: vw_pres, Long Name: Pressure transport term in VW budget
#   Variable: u2_rdstr, Long Name: Pressure redistribution term in U2 budget
#   Variable: v2_rdstr, Long Name: Pressure redistribution term in V2 budget
#   Variable: w2_rdstr, Long Name: Pressure redistribution term in W2 budget
#   Variable: uw_rdstr, Long Name: Pressure redistribution term in UW budget
#   Variable: vw_rdstr, Long Name: Pressure redistribution term in VW budget
#   Variable: u2_cor, Long Name: Coriolis term in U2 budget
#   Variable: v2_cor, Long Name: Coriolis term in V2 budget
#   Variable: uw_cor, Long Name: Coriolis term in UW budget
#   Variable: vw_cor, Long Name: Coriolis term in VW budget
#   Variable: u2_diff, Long Name: Total diffusive term in U2 budget
#   Variable: v2_diff, Long Name: Total diffusive term in V2 budget
#   Variable: w2_diff, Long Name: Total diffusive term in W2 budget
#   Variable: tke_diff, Long Name: Total diffusive term in TKE budget
#   Variable: uw_diff, Long Name: Total diffusive term in UW budget
#   Variable: vw_diff, Long Name: Total diffusive term in VW budget
#   Variable: w2_buoy, Long Name: Buoyancy production/destruction term in W2 budget
#   Variable: tke_buoy, Long Name: Buoyancy production/destruction term in TKE budget
#   Variable: uw_buoy, Long Name: Buoyancy production/destruction term in UW budget
#   Variable: vw_buoy, Long Name: Buoyancy production/destruction term in VW budget
#   Variable: b2_shear, Long Name: Shear production term in B2 budget
#   Variable: b2_turb, Long Name: Turbulent transport term in B2 budget
#   Variable: bw_shear, Long Name: Shear production term in B2 budget
#   Variable: bw_turb, Long Name: Turbulent transport term in B2 budget
#   Variable: b2_visc, Long Name: Viscous transport term in B2 budget
#   Variable: b2_diss, Long Name: Dissipation term in B2 budget
#   Variable: bw_visc, Long Name: Viscous transport term in BW budget
#   Variable: bw_diss, Long Name: Dissipation term in BW budget
#   Variable: bw_rdstr, Long Name: Redistribution term in BW budget
#   Variable: bw_buoy, Long Name: Buoyancy term in BW budget
#   Variable: bw_pres, Long Name: Pressure transport term in BW budget
#   Variable: wwtheta, Long Name: No long_name attribute

# %% [markdown]
# ### Making Variables and Constants
#
# We start off with the necessary variables. First we must decide on a time averaging parameter. We will use 15 minutes:

# %%
#choosing a time_avg parameter: 
time_avg = 15

# %%
sigma_th, sigma_2, Theta, wtheta, wwtheta, rdstr, transport = make_variables(path, selected_files, time_avg)

z = example_df.variables['z'][:]
zh = example_df.variables['zh'][:]
t = example_df.variables['time'][:]
dTheta_dz = np.gradient(Theta, z, axis = 1)
dwwtheta_dz = np.gradient(wwtheta, zh, axis = 1)

# %% [markdown]
# Sanity (order of magnitude) checks:

# %%
print("dTheta_dz", dTheta_dz.shape, np.mean(dTheta_dz), np.std(dTheta_dz))
print("sigma_th", sigma_th.shape, np.mean(sigma_th), np.std(sigma_th))
print("sigma_2", sigma_2.shape, np.mean(sigma_2), np.std(sigma_2))
print("Theta", Theta.shape, np.mean(Theta), np.std(Theta))
print("wtheta", wtheta.shape, np.mean(wtheta), np.std(wtheta))
print("wwtheta", wwtheta.shape, np.mean(wwtheta), np.std(wwtheta))
print("dwwtheta_dz", dwwtheta_dz.shape, np.mean(dwwtheta_dz), np.std(dwwtheta_dz))
print("rdtsr", rdstr.shape, np.mean(rdstr), np.std(rdstr))
print("transport", transport.shape, np.mean(transport), np.std(transport))
# Out:
# dTheta_dz (82, 384) 0.003963647167860588 0.00465853542139092
# sigma_th (82, 384) 0.011884039967426343 0.01781884043464204
# sigma_2 (82, 385) 0.2143194520546861 0.2868845719924503
# Theta (82, 384) 303.9102511671008 3.6245027161767904
# wtheta (82, 385) 0.008187199174384964 0.021235457033364467
# wwtheta (82, 385) 0.008443124 0.019204466
# dwwtheta_dz (82, 385) 7.007907371582168e-08 0.0001217516532677598
# rdtsr (82, 385) -6.665098906347553e-06 2.3542480113465666e-05
# transport (82, 385) -1.1689012605362026e-06 2.196535488745957e-05

# %%
print(wwtheta[1,0:3])
print((wwtheta[1,0]+wwtheta[1,1])/2, (wwtheta[1,1]+wwtheta[1,2])/2)
# Out:
# [ 0.0000000e+00 -3.1880256e-05 -1.0963364e-04]
# -1.594012792338617e-05 -7.075694884406403e-05

# %% [markdown]
# Variables that have a second dimension of 385 are calculated at zh values of 0, 6, 12, and so on. Variables with 384 are staggered and calculated in between there, at values of 3, 9, 15, and so on. We reshape the 385's to be 384's by taking the average of each consecutive pair.
#
# We test if this works above and below with old and new values of `wwtheta` (just a sanity check)

# %%
sigma_2 = reshape_variables(sigma_2)
wtheta = reshape_variables(wtheta)
wwtheta = reshape_variables(wwtheta)
dwwtheta_dz = reshape_variables(dwwtheta_dz)
rdstr = reshape_variables(rdstr)
transport = reshape_variables(transport)

# %%
print("dTheta_dz", dTheta_dz.shape, np.mean(dTheta_dz), np.std(dTheta_dz))
print("sigma_th", sigma_th.shape, np.mean(sigma_th), np.std(sigma_th))
print("sigma_2", sigma_2.shape, np.mean(sigma_2), np.std(sigma_2))
print("Theta", Theta.shape, np.mean(Theta), np.std(Theta))
print("wtheta", wtheta.shape, np.mean(wtheta), np.std(wtheta))
print("wwtheta", wwtheta.shape, np.mean(wwtheta), np.std(wwtheta))
print("dwwtheta_dz", dwwtheta_dz.shape, np.mean(dwwtheta_dz), np.std(dwwtheta_dz))
print(wwtheta[1,0:2])
# Out:
# dTheta_dz (82, 384) 0.003963647167860588 0.00465853542139092
# sigma_th (82, 384) 0.011884039967426343 0.01781884043464204
# sigma_2 (82, 384) 0.2148775756277452 0.28702581891303003
# Theta (82, 384) 303.9102511671008 3.6245027161767904
# wtheta (82, 384) 0.008134205981178014 0.021152086231226993
# wwtheta (82, 384) 0.008465109801873929 0.019221094530878103
# dwwtheta_dz (82, 384) -6.146483502835338e-14 0.00012119911338346663
# [-1.594012792338617e-05 -7.075694884406403e-05]

# %% [markdown]
# We plot all variables just to make sure they look correct:

# %%
timeStep = 6

plt.figure(figsize = (10, 6))

# Plot potentialTemp
plt.subplot(1, 3, 1)
#plt.plot(Theta[timeStep], np.arange(0, len(Theta[timeStep,:])))
plt.plot(Theta[timeStep], z)
plt.title('Theta(th)')
# plt.xlabel('Value')
plt.ylabel('Depth')

# Plot th_diff
plt.subplot(1, 3, 2)
# plt.plot(dTheta_dz[timeStep], np.arange(0, len(dTheta_dz[timeStep,:])))
plt.plot(dTheta_dz[timeStep], z)
plt.title('dTheta_dz')
plt.xlabel('Value')
# plt.ylabel('Depth')

# Plot th_flux
plt.subplot(1, 3, 3)
# plt.plot(wtheta[timeStep], np.arange(0, len(wtheta[timeStep,:])))
plt.plot(wtheta[timeStep], z)
plt.title('wtheta (th_flux)')
# plt.xlabel('Value')
# plt.ylabel('Depth')


plt.figure(figsize = (12, 6))

# Plot potentialTemp
plt.subplot(1, 4, 1)
# plt.plot(sigma_th[timeStep], np.arange(0, len(sigma_th[timeStep,:])))
plt.plot(sigma_th[timeStep], z)
plt.title('theta2bar (sigma_th)')
# plt.xlabel('Value')
plt.ylabel('Depth')

# Plot th_diff
plt.subplot(1, 4, 2)
# plt.plot(sigma_2[timeStep], np.arange(0, len(sigma_2[timeStep,:])))
plt.plot(sigma_2[timeStep], z)
plt.title('sigma_w^2 (sigma_2)')
plt.xlabel('Value')
# plt.ylabel('Depth')

# Plot th_flux
plt.subplot(1, 4, 3)
# plt.plot(wwtheta[timeStep], np.arange(0, len(wwtheta[timeStep,:])))
plt.plot(wwtheta[timeStep], z)
plt.title('(wwtheta)')
# plt.xlabel('Value')
# plt.ylabel('Depth')

plt.subplot(1, 4, 4)
# plt.plot(dwwtheta_dz[timeStep], np.arange(0, len(dwwtheta_dz[timeStep,:])))
plt.plot(dwwtheta_dz[timeStep], z)
plt.title('(dwwtheta_dz)')
# plt.xlabel('Value')
# plt.ylabel('Depth')
# Out:
# Text(0.5, 1.0, '(dwwtheta_dz)')

# %% [markdown]
# Now let's make our constants, and sanity check them:

# %%
wtheta_surface, pbl_height, wstar, theta_star, scaling, ustar, grr, T_0, beta, ug, q = make_constants(path, selected_files, time_avg)

# %%
print("wtheta_surface", wtheta_surface.shape, np.mean(wtheta_surface), np.std(wtheta_surface))
print("pbl_height", pbl_height.shape, np.mean(pbl_height), np.std(pbl_height))
print("wstar", wstar.shape, np.mean(wstar), np.std(wstar))
print("theta_star", theta_star.shape, np.mean(theta_star), np.std(theta_star))
print("scaling", scaling.shape, np.mean(scaling), np.std(scaling))
print("ustar", ustar.shape, np.mean(ustar), np.std(ustar))
print("grr", grr)
print("T_0", T_0)
print("beta", beta)
print("ug", ug.shape, np.mean(ug), np.std(ug))
print("q", q.shape, np.mean(q), np.std(q))
# Out:
# wtheta_surface (82, 1) 0.05707317073170729 0.03365853658536582
# pbl_height (82, 1) 1021.0731707317074 97.1732599582934
# wstar (82, 1) 1.1874402247535119 0.2901687297287799
# theta_star (82, 1) 0.0438071831979399 0.01769722969945113
# scaling (82, 1) 7.292094821455066e-05 5.185090852420291e-05
# ustar (82, 1) 0.4162597045374181 0.1812825546672867
# grr 9.8
# T_0 300
# beta 0.03266666666666667
# ug (82, 1) 9.024390243902438 5.633037584915935
# q (82, 1) 3.951219512195122 2.9955350473842035

# %% [markdown]
# ## Computing P
#
# We want to compute the $P$ term.
#
# In the paper, Equation (11) for the heat flux budget in the convective boundary layer is:
#
# $$
# \frac{\partial \overline{w \theta}}{\partial t}=0=\underbrace{-\sigma_w^2 \frac{\mathrm{d} \Theta}{\mathrm{d} z}}_M \underbrace{-\frac{\mathrm{d} \overline{w w \theta}}{\mathrm{d} z}}_T \underbrace{-\frac{1}{\rho_0} \theta \frac{\mathrm{d} p}{\mathrm{~d} z}}_P \underbrace{+\beta \overline{\theta^2}}_B
# $$
#
# Production terms: Mean gradient production ($M$), and bouyancy production ($B$). Destruction terms: turbulent flux transport ($T$) and the the pressure gradient–potential temperature covariance ($P$). Here, **P can be computed as a residual**.
#
# $P$ acts as a destruction/sink term for the heat flux $\overline{w \theta}$. Equation (12) provides a parametrization for $P$ as:
#
# $$
# P=-\frac{1}{\rho_0} \overline{\theta \frac{\mathrm{d} p}{\mathrm{~d} z}}=-C_1 \frac{\overline{w \theta}}{\tau_1} - C_2 \beta \overline{\theta^2} + C_3 \sigma_w^2 \frac{\mathrm{d} \Theta}{\mathrm{d} z}
# $$
#
# The first term $-C_1 \frac{\overline{w \theta}}{\tau_1}$ is the "slow" term. It is Rotta's return to isotropy part. Is inversely proportional to time scale $\tau_1$. I think it may also be called the "turbulence-turbulence" interaction. The last two terms are the "rapid" part, with $C_2 \beta \overline{\theta^2}$ being the bouyancy term, and $C_3 \sigma_w^2 \frac{\mathrm{d} \Theta}{\mathrm{d} z}$ being the shear-turbulence term.

# %% [markdown]
# ___
#
# **Goal:**
#
# We compute $P$ as a residual, and then see if we can reconstruct it using the variables from the parametrization ($\overline{w \theta}, \overline{\theta^2}, \sigma_w^2, \frac{\mathrm{d} \Theta}{\mathrm{d} z}$).
#
# If the residual looks different from the direct compute, this means the constants ($C_1, C_2, C_3$) probably need some modification. We may add in other variables such as Wind `ug`, Surface heating `q`, `wstar`, and `ustar` along with others later.
#
# Computing `P` as residual using Eq 11:

# %%
#computing as residual 
M = (- sigma_2 * dTheta_dz)
T = - dwwtheta_dz
B = (beta * sigma_th)

P = - M - T - B
print(P.shape)
print(f"{np.mean(B):.7f}, {np.std(B):.7f}")
print(f"{np.mean(M):.7f}, {np.std(M):.7f}")
print(f"{np.mean(T):.7f}, {np.std(T):.7f}")
print(f"{np.mean(P):.7f}, {np.std(P):.7f}")
max(P[6])/min(P[6])
# Out:
# (82, 384)
# 0.0003882, 0.0005821
# -0.0001232, 0.0003159
# 0.0000000, 0.0001212
# -0.0002650, 0.0003853
# -0.013478176706221048

# %% [markdown]
# Also computing `P` directly using Eq 12.

# %%
tau1 = 600 #unsure about this one at the moment, it is in seconds so this is ten minutes. maybe this is reasonable. 


#ADD TAU RIGHT HERE 
tau = pbl_height/wstar #length scale/velocity scale

C1 = 3
C2 = 5/12
C3 = 2/5
# C1 = 2
# C2 = 9/12
# C3 = 1/2
P_direct = - (C1 * wtheta/tau) - (C2 * beta * sigma_th) + (C3 * sigma_2 * dTheta_dz)

# %% [markdown]
# Let's see how the two compare:

# %%
timeStep = 6

plt.figure(figsize=(10, 6))

# Plot P_direct
plt.plot(P_direct[timeStep] * pbl_height[timeStep] / (wstar[timeStep] * theta_star[timeStep]), z, label='P (direct from eq 12)', color = "firebrick")

# Plot P residual
plt.plot(P[timeStep] * pbl_height[timeStep] / (wstar[timeStep] * theta_star[timeStep]), z, label='P (residual from eq 11)', color = "black")

plt.ylim(0, 2000)
plt.title('Comparison of P values')
plt.xlabel('Value')
plt.ylabel('Depth')
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# **Note:** Changing the C's can get the directly computed P to look much more like the residual P. If we assume the residual is correct, this means these coefficients could use some work! C2 and C3 seem to have the most effect, with C1 not doing much except changing the shape of the down in the lower ABL. C2 and C3 can really get it to jump out at the inversion layer like the residual.
#
# A more detailed plot:

# %%
timeStep = 10

plt.figure(figsize=(10, 6))

plt.plot(P[timeStep], z, label = 'P (residual, eq 11)', color = "black")
plt.plot(-0.004997506 * wtheta[timeStep], z, label = r'$- C_1 * \overline{w\theta} / \tau$', color = "dodgerblue")
plt.plot(-0.019068547 * sigma_th[timeStep], z, label = r'$- C_2 * \beta * \overline{\theta^2}$', color = "lightseagreen")
plt.plot(sigma_2[timeStep] * dTheta_dz[timeStep] * 2/5, z, label = r'$\sigma_w^2 * \frac{d\Theta}{dz}$', color = "mediumslateblue")

plt.ylim(0, 2000)
plt.title('The ingredients of P')
plt.xlabel('Value')
plt.ylabel('Depth')
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# ### Equation Discovery
#
# Let's begin setting up a model to compute `P` from those variables. We will use all moments in time, almost all of our simulations, and most of the ABL vertically. Smaller experiments were tried in our earlier notebook `Steps_to_EQ-Rotta_Sikorski.ipynb` and did not produce nearly as good of results.

# %%
indices = np.s_[:, 0:200]

y = P[indices].ravel()

x0 = wtheta[indices].ravel()
x1 = sigma_th[indices].ravel()
x2 = sigma_2[indices].ravel()
x3 = dTheta_dz[indices].ravel()
X = np.column_stack([x0, x1, x2, x3])

df_X = pd.DataFrame(X, columns=['wtheta', 'sigma_th', 'sigma_2', 'dTheta_dz'])
df_y = pd.DataFrame(y, columns=['P'])
print(df_X.shape, df_y.shape)
# Out:
# (16400, 4) (16400, 1)

# %%
model = PySRRegressor(
    niterations=10000,  # increase me for better results
    maxsize = 24, # allowing for appropriate complexity (x + y has size 3)
    maxdepth = 4, # avoiding deep nesting
    progress = False, # makes the printout less hectic in Jupyter
    binary_operators=["+", "*", "-", "/"],
    # unary_operators=[
    #     "cos",
    #     "exp",
    #     "sin",
    #     "inv(x) = 1/x",
    #     "square",
    #     "cube",
    #     # ^ Custom operator (julia syntax)
    # ],
    # extra_sympy_mappings={"inv": lambda x: 1 / x},
    # ^ Define operator for SymPy as well
    elementwise_loss="loss(prediction, target) = (prediction - target)^2",
    # ^ Custom loss function (julia syntax)
    batching = True,
    batch_size = 250,
    complexity_of_operators={"*": 1, "+": 1, "-": 1,
                             "exp": 3, "sin": 3, "cos": 3, 
                             "inv": 3, "square": 3, "cube": 3},
    # ^ Custom complexity of particular operators
)

# add max depth and max size options
# use a custom loss function?

# %%
model.fit(df_X,df_y)

# %%
equations = model.equations_
print(equations.shape)
display(equations)
print("Final Equation: ")
display(equations.iloc[4, 4])
print(equations.iloc[-1, 4])

# %% [markdown]
# Let's look at some past discovered eq's:

# %%
discovered_eq1 = (-0.004997506 * wtheta) - (sigma_th * 0.019068547)
discovered_eq2 = (((sigma_th * wtheta) + (sigma_2 * 0.4073766)) * dTheta_dz) - (0.02337299 * (sigma_th + (0.13268535 * wtheta)))
# discovered_eq3 = (dTheta_dz * sigma_2 * ((0.61661136 - wtheta))) - 0.0271534 * sigma_th

# %%
#EQUATION 1
# discovered value in front of sigma_th is -0.019068547 or - 0.02337299
print(- C2*beta)
#close enough\

#discovered value in front of wtheta is -0.004997506
print(- C1/tau1)
# also close enough


#EQUATION 2
#as far as eq2 goes, it appears that the added multiplication is not of an important size
print(np.mean(abs(sigma_th[timeStep] * wtheta[timeStep] * dTheta_dz[timeStep])))
print(np.mean(abs(dTheta_dz[timeStep] * sigma_2[timeStep] * 0.4)))

8/12 * beta # so it appears C2 should be larger, maybe 8/12 instead of 5/12

print(C1)
print(3/tau1)
print(2/tau1)
print(3/1000)
0.02337299 * 0.13268535

# so either tau1 needs to be 1000 or C1 needs to be 2 instead of 3
# Out:
# -0.013611111111111114
# -0.005
# 3.745525378677423e-07
# 9.987698048903196e-05
# 3
# 0.005
# 0.0033333333333333335
# 0.003
# 0.0031012533586965

# %% [markdown]
# Plotting to answer some questions (below):

# %%
timeStep = 10

plt.figure(figsize=(10, 6))

plt.plot(P[timeStep], z, label = 'P (residual, eq 11)', color = "black")

plt.plot(discovered_eq1[timeStep], z, label = 'EQ1 (no 3rd term)', color = 'coral')
plt.plot(discovered_eq2[timeStep], z, label = 'EQ2 (extra multiplies)', color = 'goldenrod')
# plt.plot(discovered_eq3[timeStep], z, label = 'EQ3 (no 3rd term)', color = 'darkorange')

plt.ylim(0, 2000)
plt.title('Discovered Equations')
plt.xlabel('Value')
plt.ylabel('Depth')
plt.legend()
plt.grid(True)

plt.show()

# %%
plt.scatter(y, model.predict(X))
plt.xlabel('Truth')
plt.ylabel('Prediction')
plt.show()

# %% [markdown]
# Lets try passing in the last term ($\sigma_w^2 * \frac{d\Theta}{dz}$) as one, and see if that works:

# %%
# our new term (Multi)
x4 = (sigma_2[indices] * dTheta_dz[indices]).ravel()

X_mult = np.column_stack([x0, x1, x4])

df_X_mult = pd.DataFrame(X_mult, columns=['wtheta', 'sigma_th', 'Multi'])
df_y_mult = pd.DataFrame(y, columns=['P'])
print(df_X_mult.shape, df_y_mult.shape)
# Out:
# (16400, 3) (16400, 1)

# %%
model_mult = PySRRegressor(
    niterations=4000,  # increase me for better results
    maxsize = 18, # allowing for appropriate complexity (x + y has size 3)
    maxdepth = 4, # avoiding deep nesting
    progress = False, # makes the printout less hectic in Jupyter
    binary_operators=["+", "*", "-", "/"],
    # unary_operators=[
    #     "cos",
    #     "exp",
    #     "sin",
    #     "inv(x) = 1/x",
    #     "square",
    #     "cube",
    #     # ^ Custom operator (julia syntax)
    # ],
    # extra_sympy_mappings={"inv": lambda x: 1 / x},
    # ^ Define operator for SymPy as well
    elementwise_loss="loss(prediction, target) = (prediction - target)^2",
    # ^ Custom loss function (julia syntax)
    batching = True,
    batch_size = 250,
    complexity_of_operators={"*": 1, "+": 1, "-": 1,
                             "exp": 3, "sin": 3, "cos": 3, 
                             "inv": 3, "square": 3, "cube": 3},
    # ^ Custom complexity of particular operators
)

# add max depth and max size options
# use a custom loss function?

# %%
model_mult.fit(df_X_mult,df_y_mult);

# %%
equations_mult = model_mult.equations_
print(equations_mult.shape)
display(equations_mult)
print("Final Equation: ")
display(equations_mult.iloc[-1, 4])
print(equations_mult.iloc[-1,3])

# %% [markdown]
# next step: look at the relative sizes of each term and see if it caught it correctly.

# %%
discovered_eq4 = (0.44425 * sigma_2 * dTheta_dz) - 0.02413 * sigma_th*(sigma_th + 0.94514) - 0.00279*wtheta

# print(np.mean(abs(0.02413 * sigma_th**2)))
# print(np.mean(abs(0.02413 * 0.94514 * sigma_th)))
# print(np.mean(abs(0.00279 * wtheta)))
# print(np.mean(abs(0.44425 * sigma_2 * dTheta_dz)))

discovered_eq5 = 0.47018164 * sigma_2 * dTheta_dz - 0.0248089397328638 * sigma_th - 0.0024893184 * wtheta

print(np.mean(abs(0.0248089397328638 * sigma_th)))
print(np.mean(abs(0.0024893184 * wtheta)))
print(np.mean(abs(0.47018164 * sigma_2 * dTheta_dz)))
# Out:
# 0.00029483043133482484
# 2.6731871883419068e-05
# 8.70038511307267e-05

# %%
timeStep = 10

plt.figure(figsize=(10, 6))

plt.plot(P[timeStep], z, label = 'P (residual, eq 11)', color = "black")

# plt.plot(discovered_eq1[timeStep], z, label = 'EQ1 (no 3rd term)', color = 'forestgreen')
# plt.plot(discovered_eq2[timeStep], z, label = 'EQ2 (extra multiplies)', color = 'goldenrod')

plt.plot(discovered_eq4[timeStep], z, label = 'EQ4 (extra sigma_th^2)', color = 'darkmagenta')
plt.plot(discovered_eq5[timeStep], z, label = 'EQ5 (correct)', color = 'forestgreen')

plt.ylim(0, 1200)
plt.title('Discovered Equations')
plt.xlabel('Value')
plt.ylabel('Depth')
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# This is a good model, let's make sure we save it and know which one it is:

# %%
model_mult_success1 = PySRRegressor.from_file("past_models/first_success_mult.pkl")
# Out:
# Checking if past_models/first_success_mult.pkl exists...
# Loading model from past_models/first_success_mult.pkl

# %%
# plt.scatter(df_y_mult, model_mult_success1.predict(df_X_mult), color = "forestgreen", alpha = 0.5)
# plt.xlabel('True P')
# plt.ylabel('Predicted P')
# plt.title('First Successful Eq Discovery for P')
# plt.show()

predicted_values = model_mult_success1.predict(df_X_mult)

plt.scatter(df_y_mult, predicted_values, color="forestgreen", alpha=0.5)
plt.plot([min(df_y_mult.min()), max(df_y_mult.max())], 
         [min(df_y_mult.min()), max(df_y_mult.max())], 
         'k--', label='y = x')
plt.xlabel('True P')
plt.ylabel('Predicted P')
plt.title('First Successful Eq Discovery for P')
plt.legend()
plt.show()

yhat = np.array( model_mult_success1.predict(df_X_mult))
y = df_y_mult['P'].values

# Calculating the metrics
rmse = np.sqrt(np.mean((yhat - y)**2))
mae = np.mean(np.abs(yhat - y))
r2 = 1 - np.sum((y - yhat)**2) / np.sum((y - np.mean(y))**2)
mape = np.mean(np.abs((y - yhat) / y))
mean_abs_p = np.mean(np.abs(y))

# Printing the metrics to 7 decimal places using f-strings
print(f"RMSE: {rmse:.7f}")
print(f"MAE: {mae:.7f}")
print(f"R2: {r2:.7f}")
print(f"MAPE: {mape:.7f}")
print(f"Mean Size (Amplitude) of P: {mean_abs_p:.7f}")
# Out:
# RMSE: 0.0000694
# MAE: 0.0000425
# R2: 0.9808927
# MAPE: 1.0389161
# Mean Size (Amplitude) of P: 0.0003344

# %% [markdown]
# Let's also take a quick peek at the coefficient sizes:

# %%
#P_direct = - (C1 * wtheta/tau) - (C2 * beta * sigma_th) + (C3 * sigma_2 * dTheta_dz)
# original P equation for guidance above

#meanwhile, our first successful discovery was: 
# discovered_eq5 = 0.47018164 * sigma_2 * dTheta_dz - 0.0248089397328638 * sigma_th - 0.0024893184 * wtheta

#in front of wtheta: 

print("Coefficient Magnitudes: ")
print(f"wtheta: Original -C1/tau : {-np.mean(np.abs(C1/tau)):.7f}, Discovered:  {-0.0024893184:.7f}")
print(f"sigma_th: Original -C2 * beta : {- C2 * beta:.7f}, Discovered:  {-0.0248089397328638:.7f}")
print(f"sigma_2*dTheta_dz: Original C3 : {C3:.7f}, Discovered:  {0.47018164:.7f}")

print(0.0024893/0.0034629 * 3) #set C1 to 2 rather than 3
print(0.0248089/0.0136111 * 5/12) #set C1 to be 9/12 rather than 5/12
0.4701816/0.4 * 2/5 #set C3 to be closer to 1/2 rather than 2/5
# Out:
# Coefficient Magnitudes:
# wtheta: Original -C1/tau : -0.0034629, Discovered:  -0.0024893
# sigma_th: Original -C2 * beta : -0.0136111, Discovered:  -0.0248089
# sigma_2*dTheta_dz: Original C3 : 0.4000000, Discovered:  0.4701816
# 2.156545092263709
# 0.7594567424136672
# 0.4701815999999999

# %% [markdown]
# Okay, now let's start adding in more variables, such as `Ug`, `q`, `tau`, `ustar`.

# %%
ug_expand = np.repeat(ug, 384, axis=1)
q_expand = np.repeat(q, 384, axis=1)
tau_expand = np.repeat(tau, 384, axis=1)
ustar_expand = np.repeat(ustar, 384, axis=1)

# %%
indices = np.s_[:, 0:200]

x0 = wtheta[indices].ravel()
x1 = sigma_th[indices].ravel()

# x2 = sigma_2[indices].ravel()
# x3 = dTheta_dz[indices].ravel()

x4 = (sigma_2[indices] * dTheta_dz[indices]).ravel()

ug_expand_d = ug_expand[indices].ravel()
q_expand_d = q_expand[indices].ravel()
tau_expand_d = tau_expand[indices].ravel()
ustar_expand_d = ustar_expand[indices].ravel()

# X_expand = np.column_stack([x0, x1, x2, x3, ug_expand_d, q_expand_d, tau_expand_d, ustar_expand_d])
X_expand = np.column_stack([x0, x1, x4, ug_expand_d, q_expand_d, tau_expand_d, ustar_expand_d])

# df_X_expand = pd.DataFrame(X_expand, columns=['wtheta', 'sigma_th', 'sigma_2', 'dTheta_dz', 'ug', 'q', 'tau', 'ustar'])
df_X_expand = pd.DataFrame(X_expand, columns=['wtheta', 'sigma_th', 'Multi', 'ug', 'q', 'tau', 'ustar'])
print(df_X_expand.shape, df_y.shape)
# Out:
# (16400, 7) (16400, 1)

# %%
model_expand = PySRRegressor(
    niterations = 10000,  # increase me for better results
    maxsize = 28, # allowing for appropriate complexity (x + y has size 3)
    maxdepth = 4, # avoiding deep nesting
    progress = False, # makes the printout less hectic in Jupyter
    binary_operators=["+", "*", "-", "/"],
    # unary_operators=[
    #     "cos",
    #     "exp",
    #     "sin",
    #     "inv(x) = 1/x",
    #     "square",
    #     "cube",
    #     # ^ Custom operator (julia syntax)
    # ],
    # extra_sympy_mappings={"inv": lambda x: 1 / x},
    # ^ Define operator for SymPy as well
    elementwise_loss="loss(prediction, target) = (prediction - target)^2",
    # ^ Custom loss function (julia syntax)
    batching = True,
    batch_size = 250,
    complexity_of_operators = {"*": 1, "+": 1, "-": 1,
                             "exp": 3, "sin": 3, "cos": 3, 
                             "inv": 3, "square": 3, "cube": 3},
    complexity_of_constants = 3,
    # ^ Custom complexity of particular operators
)

# add max depth and max size options
# use a custom loss function?

# %%
model_expand.fit(df_X_expand,df_y)

# %%
equations_expand = model_expand.equations_
print(equations_expand.shape)
display(equations_expand)
print("Final Equation: ")
display(equations_expand.iloc[10, 4])
print(equations_expand.iloc[10,3])

# %%
discovered_eq6 = 0.5939527 * dTheta_dz * (sigma_2 + 0.0053609144) - 0.0256792369321674 * sigma_th - 5.65938282938803 * 10**(-5)
discovered_eq7 = - (0.0024532885 * wtheta) - (0.02480443 * sigma_th) + (0.464882 * (dTheta_dz * sigma_2)) 
discovered_eq8 = - (0.00274849360541487 * wtheta) - (0.024669657 * sigma_th) + (0.45000073 * (dTheta_dz * sigma_2))

# %% [markdown]
# It appears that if one term has to go, it's always the wtheta that goes, so maybe the Rotta model isn't so great. If all three terms are discovered, the size of the Rotta coefficient decreases, the size of the theta^2 coefficient increases, and the size of the last multiplied term slightly increases from like 0.4 to 0.47ish.

# %%
plt.figure(figsize=(10, 6))

timeStep = 10

plt.plot(P[timeStep], z, label = 'P (residual, eq 11)', color = "black")

plt.plot(discovered_eq6[timeStep], z, label = 'EQ6 (not quite, also no Rotta)', color = 'darkorange')
plt.plot(discovered_eq7[timeStep], z, label = 'EQ7 (newest, corect)', color = 'orchid')
# plt.plot(discovered_eq3[timeStep], z, label = 'EQ3 (no 3rd term)', color = 'darkorange')

plt.ylim(0, 2000)
plt.title('Discovered Equations')
plt.xlabel('Value')
plt.ylabel('Depth')
plt.legend()
plt.grid(True)

plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.plot(wtheta[timeStep], z, label = 'wtheta (true)', color = "black")

plt.ylim(0, 2000)
plt.title('Comparing Heat Flux')
plt.xlabel('Value')
plt.ylabel('Depth')
plt.legend()
plt.grid(True)

plt.show()

# %%
indices = np.s_[:, 0:200]


def make_wtheta(C1, C2, C3):
    wtheta_temp = ((C3 - 1)/C1) * tau * sigma_2 * ( dTheta_dz - ( (1/( sigma_2 * (C3 - 1))) * dwwtheta_dz) + ((1 - C2) * beta * sigma_th)/((C3 -1) * sigma_2) ) -((C3 - 1)/C1) * tau * sigma_2 * (    - ( (1/( sigma_2 * (C3 - 1))) * dwwtheta_dz))
    return wtheta_temp

# here i take the mean of the gradient of dwwtheta_dz
# def make_wtheta(C1, C2, C3):
#     wtheta_temp = ((C3 - 1)/C1) * tau * sigma_2 * ( dTheta_dz - ( (1/( sigma_2 * (C3 - 1))) * np.mean(dwwtheta_dz)) + ((1 - C2) * beta * sigma_th)/((C3 -1) * sigma_2) )
#     return wtheta_temp

wtheta_paper = make_wtheta(3, 5/12, 2/5)
wtheta_discovered = make_wtheta(2.1565, 0.7594,0.4702)

#play around with this manual adjustment and get it close
wtheta_a = make_wtheta(7, 0.7, 0.2)

# %%
plt.figure(figsize=(10, 6))

timeStep = 20
plt.plot(wtheta[timeStep], z, label = 'wtheta (true)', color = "black")
# plt.plot(wtheta_paper[timeStep], z, label = 'wtheta (Coefficients from paper)', color = "dodgerblue")
plt.plot(wtheta_discovered[timeStep], z, label = 'wtheta (Discovered)', color = "firebrick")

#play around with this manual adjustment and get it close
plt.plot(wtheta_a[timeStep], z, label = 'wtheta (manually adjusted)', color = "green")

dominating_term = ((C3 - 1)/C1) * tau * sigma_2 * (    - ( (1/( sigma_2 * (C3 - 1))) * dwwtheta_dz))
# plt.plot( dominating_term[timeStep], z, label = 'dominating dwwtheta_dz term', color = "darkorange")

plt.ylim(0, 2000)
plt.title('Comparing Heat Flux')
plt.xlabel('Value')
plt.ylabel('Depth')
plt.legend()
plt.grid(True)

# plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
plt.figure(figsize=(10, 6))

#two plots, one scatter of true vs paper, the other a scatter of true vs discovered
#make these two subplots
plt.subplot(1, 2, 1)
plt.scatter(wtheta[timeStep], wtheta_paper[timeStep], color = "dodgerblue", alpha = 0.5)
plt.xlabel('True wtheta')
plt.ylabel('Predicted wtheta')
plt.title('Paper Coefficients')
#add a y=x line
plt.plot(np.linspace(0, 0.2, 100), np.linspace(0, 0.2, 100), color = "black")
# plt.xlim(0,0.2)
# plt.ylim(0,0.2)
# plt.show()

plt.subplot(1, 2, 2)
plt.scatter(wtheta[timeStep], wtheta_discovered[timeStep], color = "firebrick", alpha = 0.5)
plt.xlabel('True wtheta')
plt.ylabel('Predicted wtheta')
plt.title('Discovered Coefficients')
# plt.xlim(0,0.2)
# plt.ylim(0,0.2)
plt.plot(np.linspace(0, 0.2, 100), np.linspace(0, 0.2, 100), color = "black")
plt.show()

# %%
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df_X_mult, df_y_mult, test_size=0.2, random_state=42)

# Create and train the model
model = LinearRegression()
model.fit(X_train, y_train)

# Predict on the test set
y_pred = model.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")

coefficients = model.coef_[0]  # Since coef_ returns a 2D array for multi-output, we take the first element
intercept = model.intercept_[0]  # Similarly, intercept_ returns a 1D array for multi-output

for col, coef in zip(df_X.columns, coefficients):
    print(f"Coefficient for {col}: {coef}")
print(f"Intercept: {intercept}")
# Out:
# Mean Squared Error: 4.726432730111873e-09
# R-squared: 0.9827340049250761
# Coefficient for wtheta: -0.002601604852556511
# Coefficient for sigma_th: -0.024363189485590714
# Coefficient for sigma_2: 0.4466854665119868
# Intercept: -6.718423225398804e-06

# %%
print(np.min(ustar), np.max(ustar), np.mean(ustar), np.std(ustar))
# Out:
# 0.15281354735900424 0.7101019777476506 0.4162597045374181 0.1812825546672867

# %%
ustar_test = - (0.0024532885 * x0) - (0.02480443 * x1) + (0.75 * ustar_expand_d * (x3 * x2))

# Calculating the metrics
rmse = np.sqrt(np.mean((ustar_test - y)**2))
mae = np.mean(np.abs(ustar_test - y))
r2 = 1 - np.sum((y - ustar_test)**2) / np.sum((y - np.mean(y))**2)
mape = np.mean(np.abs((y - ustar_test) / y))

# Printing the metrics to 7 decimal places using f-strings
print(f"RMSE: {rmse:.7f}")
print(f"MAE: {mae:.7f}")
print(f"R2: {r2:.7f}")
print(f"MAPE: {mape:.7f}")
# Out:
# RMSE: 0.0000969
# MAE: 0.0000522
# R2: 0.9627694
# MAPE: 1.0753994

# %%
plt.scatter(y, ustar_test, color="forestgreen", alpha=0.5)
plt.plot([min(y.min(), ustar_test.min()), max(y.max(), ustar_test.max())], 
         [min(y.min(), ustar_test.min()), max(y.max(), ustar_test.max())], 
         'k--', label='y = x')
plt.xlabel('True P')
plt.ylabel('Predicted P')
plt.title('First Successful Eq Discovery for P')
plt.legend()
plt.show()

# %% [markdown]
# Putting ustar in front of 3rd term provides comparable results!

# %% [markdown]
# final presi will be:
# 1. the problem (background on turbulence, atmospheric boundary layer, etc)
# 2. the methodology (PYSR, how does it work, genetic algorithms, etc)
# 3. Re-disovery of the original equation.
# 4. Current work on improving the parametrization.
